# %% [markdown]
# # Heart Failure Prediction Assignment

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv("heart failure.csv")
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
df.shape
# Out:
# (299, 13)

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %% [markdown]
# ## Objective
# The goal of this assignment is to analyze the **heart failure clinical records** dataset and build a machine learning model to predict the occurrence of a **death event** in patients with heart failure. You will perform exploratory data analysis (EDA), visualize trends, and apply classification models to predict the target variable.
#
# ## Dataset Overview
#
# The dataset consists of 13 variables, each representing clinical features and demographic information of heart failure patients:
#
# 1. **age**: Age of the patient (years)
# 2. **anaemia**: Whether the patient has anaemia (0: no, 1: yes)
# 3. **creatinine_phosphokinase**: Level of the CPK enzyme in the blood (mcg/L)
# 4. **diabetes**: Whether the patient has diabetes (0: no, 1: yes)
# 5. **ejection_fraction**: Percentage of blood leaving the heart with each contraction (%)
# 6. **high_blood_pressure**: Whether the patient has high blood pressure (0: no, 1: yes)
# 7. **platelets**: Platelets in the blood (kiloplatelets/mL)
# 8. **serum_creatinine**: Level of serum creatinine in the blood (mg/dL)
# 9. **serum_sodium**: Level of serum sodium in the blood (mEq/L)
# 10. **sex**: Gender of the patient (1: male, 0: female)
# 11. **smoking**: Whether the patient smokes (0: no, 1: yes)
# 12. **time**: Follow-up period (days)
# 13. **DEATH_EVENT**: Whether the patient died during the follow-up period (0: no, 1: yes) [Target Variable]
#
# ## Instructions
#
# ### 1. Data Exploration (EDA)
# - **Task 1**: Load the dataset using pandas and display the first few rows.
# - **Task 2**: Check for missing values and clean the data if necessary.
# - **Task 3**: Generate summary statistics for the numerical columns.
# - **Task 4**: Visualize the distribution of the target variable (`DEATH_EVENT`).
# - **Task 5**: Plot histograms or box plots for continuous variables like `age`, `creatinine_phosphokinase`, `ejection_fraction`, `serum_creatinine`, etc.
#
# ### 2. Data Visualization
# - **Task 6**: Create a correlation matrix heatmap to understand the relationships between the features.
# - **Task 7**: Create count plots or bar charts for categorical variables like `anaemia`, `diabetes`, `high_blood_pressure`, `sex`, and `smoking`.
# - **Task 8**: Create scatter plots or pair plots for continuous variables like `age` vs `ejection_fraction`, `serum_creatinine`, etc., colored by `DEATH_EVENT`.
#
# ### 3. Model Building
# - **Task 9**: Split the dataset into features (`X`) and the target variable (`y = DEATH_EVENT`).
# - **Task 10**: Perform train-test splitting (70% training, 30% testing) using `train_test_split` from sklearn.
# - **Task 11**: Standardize the continuous features using `StandardScaler`.
#
# ### 4. Model Training and Evaluation
# - **Task 12**: Train a Logistic Regression model and evaluate it using accuracy, precision, recall, and F1-score.
# - **Task 13**: Train a K-Nearest Neighbors (KNN) model and evaluate its performance.
# - **Task 14**: Train a Decision Tree Classifier and compare its performance with other models.
#
# ### 5. Cross Validation
# - **Task 15**: Perform K-Fold Cross-Validation (with 5 folds) on the Logistic Regression model to evaluate its performance.
# - **Task 16**: Perform Stratified K-Fold Cross-Validation to ensure class balance during cross-validation.
#
# ### 6. Model Improvement
# - **Task 17**: Use Grid Search or Randomized Search to tune the hyperparameters of the KNN and Decision Tree models.
# - **Task 18**: Plot the ROC curves and calculate the AUC for all models to compare their performance visually.
#
# ### 7. Conclusion
# - **Task 19**: Summarize your findings and explain which model performed best and why. Consider which features were most important for predicting the death event.
# - **Task 20**: Suggest potential improvements or next steps for the analysis.
#
# ---

# %% [markdown]
# # Soluaiton :
# ## part-1
#
# ### 1. Data Exploration (EDA)
# - **Task 1**: Load the dataset using pandas and display the first few rows.
# - **Task 2**: Check for missing values and clean the data if necessary.
# - **Task 3**: Generate summary statistics for the numerical columns.
# - **Task 4**: Visualize the distribution of the target variable (`DEATH_EVENT`).
# - **Task 5**: Plot histograms or box plots for continuous variables like `age`, `creatinine_phosphokinase`, `ejection_fraction`, `serum_creatinine`,

# %% [markdown]
# ### Task 1**: Load the dataset using pandas and display the first few rows.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("heart failure.csv")

# Display first few rows
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %% [markdown]
# ### **Task 2**: Check for missing values and clean the data if necessary.

# %%
# Check for missing values
df.isnull().sum()

# If missing values are found, impute them (this is an example)
df.fillna(df.median(), inplace=True)

# %% [markdown]
# ###  **Task 3**: Generate summary statistics for the numerical columns.

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %% [markdown]
# ### **Task 4**: Visualize the distribution of the target variable (`DEATH_EVENT`).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot distribution of the target variable
sns.countplot(x='DEATH_EVENT', data=df)
plt.title('Distribution of DEATH_EVENT')
plt.show()

# %% [markdown]
# #### - **Task 5**: Plot histograms or box plots for continuous variables like
# #### `age`, `creatinine_phosphokinase`, `ejection_fraction`, `serum_creatinine`,

# %%
# Continuous variables: age, creatinine_phosphokinase, ejection_fraction, serum_creatinine
continuous_features = ['age', 'creatinine_phosphokinase', 'ejection_fraction', 'serum_creatinine']

# Plot histograms
df[continuous_features].hist(bins=20, figsize=(10, 8))
plt.tight_layout()
plt.show()

# Plot box plots
df[continuous_features].plot(kind='box', subplots=True, layout=(2, 2), figsize=(10, 8), sharex=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Part-2

# %% [markdown]
# ### 2.Data Visualization
# - **Task 6**: Create a correlation matrix heatmap to understand the relationships between the features.
# - **Task 7**: Create count plots or bar charts for categorical variables like `anaemia`, `diabetes`, `high_blood_pressure`, `sex`, and `smoking`.
# - **Task 8**: Create scatter plots or pair plots for continuous variables like `age` vs `ejection_fraction`, `serum_creatinine`, etc., colored by `DEATH_EVENT`.

# %% [markdown]
# ###  **Task 6**: Create a correlation matrix heatmap to understand the relationships between the features.

# %%
# Correlation matrix heatmap
corr_matrix = df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### - **Task 7**: Create count plots or bar charts for categorical variables like `anaemia`, `diabetes`, `high_blood_pressure`, `sex`, and `smoking`.

# %%
# Categorical variables: anaemia, diabetes, high_blood_pressure, sex, smoking
categorical_features = ['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking']

# Plot count plots
for feature in categorical_features:
    sns.countplot(x=feature, data=df)
    plt.title(f'Count plot of {feature}')
    plt.show()

# %% [markdown]
# ### **Task 8**: Create scatter plots or pair plots for continuous variables like `age` vs `ejection_fraction`, `serum_creatinine`, etc., colored by `DEATH_EVENT`.

# %%
# Scatter plot: age vs ejection_fraction colored by DEATH_EVENT
sns.scatterplot(x='age', y='ejection_fraction', hue='DEATH_EVENT', data=df)
plt.title('Age vs Ejection Fraction')
plt.show()

# Scatter plot: age vs serum_creatinine colored by DEATH_EVENT
sns.scatterplot(x='age', y='serum_creatinine', hue='DEATH_EVENT', data=df)
plt.title('Age vs Serum Creatinine')
plt.show()

# %% [markdown]
# # part-3
# ### 3. Model Building
# - **Task 9**: Split the dataset into features (`X`) and the target variable (`y = DEATH_EVENT`).
# - **Task 10**: Perform train-test splitting (70% training, 30% testing) using `train_test_split` from sklearn.
# - **Task 11**: Standardize the continuous features using `StandardScaler`.

# %% [markdown]
# ### **Task 9**: Split the dataset into features (`X`) and the target variable (`y = DEATH_EVENT`).

# %%
# Split into features and target
X = df.drop('DEATH_EVENT', axis=1)
y = df['DEATH_EVENT']

# %% [markdown]
# ###  **Task 10**: Perform train-test splitting (70% training, 30% testing) using `train_test_split` from sklearn.

# %%
from sklearn.model_selection import train_test_split

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ###  **Task 11**: Standardize the continuous features using `StandardScaler`.

# %%
from sklearn.preprocessing import StandardScaler

# Standardize continuous features
scaler = StandardScaler()
X_train[['age', 'creatinine_phosphokinase', 'ejection_fraction', 'serum_creatinine']] = scaler.fit_transform(
    X_train[['age', 'creatinine_phosphokinase', 'ejection_fraction', 'serum_creatinine']])
X_test[['age', 'creatinine_phosphokinase', 'ejection_fraction', 'serum_creatinine']] = scaler.transform(
    X_test[['age', 'creatinine_phosphokinase', 'ejection_fraction', 'serum_creatinine']])

# %% [markdown]
# # Part-4
# ### 4. Model Training and Evaluation
# - **Task 12**: Train a Logistic Regression model and evaluate it using accuracy, precision, recall, and F1-score.
# - **Task 13**: Train a K-Nearest Neighbors (KNN) model and evaluate its performance.
# - **Task 14**: Train a Decision Tree Classifier and compare its performance with other models.

# %% [markdown]
# ### **Task 12**: Train a Logistic Regression model and evaluate it using accuracy, precision, recall, and F1-score.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Logistic Regression
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

# Predictions
y_pred = lr_model.predict(X_test)

# Evaluate
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Precision: {precision_score(y_test, y_pred)}')
print(f'Recall: {recall_score(y_test, y_pred)}')
print(f'F1-score: {f1_score(y_test, y_pred)}')
# Out:
# Accuracy: 0.7777777777777778
# Precision: 0.84
# Recall: 0.5675675675675675
# F1-score: 0.6774193548387096
# C:\Users\hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ###  **Task 13**: Train a K-Nearest Neighbors (KNN) model and evaluate its performance.

# %%
from sklearn.neighbors import KNeighborsClassifier

# KNN
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)

# Predictions
y_pred_knn = knn_model.predict(X_test)

# Evaluate
print(f'KNN Accuracy: {accuracy_score(y_test, y_pred_knn)}')
print(f'KNN Precision: {precision_score(y_test, y_pred_knn)}')
print(f'KNN Recall: {recall_score(y_test, y_pred_knn)}')
print(f'KNN F1-score: {f1_score(y_test, y_pred_knn)}')
# Out:
# KNN Accuracy: 0.5888888888888889
# KNN Precision: 0.5
# KNN Recall: 0.16216216216216217
# KNN F1-score: 0.24489795918367346

# %% [markdown]
# ### **Task 14**: Train a Decision Tree Classifier and compare its performance with other models.

# %%
from sklearn.tree import DecisionTreeClassifier

# Decision Tree
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)

# Predictions
y_pred_dt = dt_model.predict(X_test)

# Evaluate
print(f'Decision Tree Accuracy: {accuracy_score(y_test, y_pred_dt)}')
print(f'Decision Tree Precision: {precision_score(y_test, y_pred_dt)}')
print(f'Decision Tree Recall: {recall_score(y_test, y_pred_dt)}')
print(f'Decision Tree F1-score: {f1_score(y_test, y_pred_dt)}')
# Out:
# Decision Tree Accuracy: 0.6444444444444445
# Decision Tree Precision: 0.5925925925925926
# Decision Tree Recall: 0.43243243243243246
# Decision Tree F1-score: 0.5

# %% [markdown]
# # part-5
# ### 5. Cross Validation
# - **Task 15**: Perform K-Fold Cross-Validation (with 5 folds) on the Logistic Regression model to evaluate its performance.
# - **Task 16**: Perform Stratified K-Fold Cross-Validation to ensure class balance during cross-validation.

# %% [markdown]
# ### **Task 15**: Perform K-Fold Cross-Validation (with 5 folds) on the Logistic Regression model to evaluate its performance.

# %%
from sklearn.model_selection import cross_val_score

# 5-Fold Cross Validation
cv_scores = cross_val_score(lr_model, X, y, cv=5, scoring='accuracy')
print(f'5-Fold CV Accuracy (Logistic Regression): {cv_scores.mean()}')
# Out:
# C:\Users\hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 5-Fold CV Accuracy (Logistic Regression): 0.7822598870056497
# C:\Users\hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
#  **Task 16**: Perform Stratified K-Fold Cross-Validation to ensure class balance during cross-validation.

# %%
from sklearn.model_selection import StratifiedKFold

# Stratified K-Fold
strat_kfold = StratifiedKFold(n_splits=5)
cv_scores_strat = cross_val_score(lr_model, X, y, cv=strat_kfold, scoring='accuracy')
print(f'Stratified K-Fold CV Accuracy: {cv_scores_strat.mean()}')
# Out:
# C:\Users\hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Stratified K-Fold CV Accuracy: 0.7822598870056497
# C:\Users\hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Part-6
# ### 6. Model Improvement
# - **Task 17**: Use Grid Search or Randomized Search to tune the hyperparameters of the KNN and Decision Tree models.
# - **Task 18**: Plot the ROC curves and calculate the AUC for all models to compare their performance visually.

# %% [markdown]
# ### **Task 17**: Use Grid Search or Randomized Search to tune the hyperparameters of the KNN and Decision Tree models.

# %%
from sklearn.model_selection import GridSearchCV

# KNN Hyperparameter tuning
knn_params = {'n_neighbors': [3, 5, 7, 9]}
grid_search_knn = GridSearchCV(KNeighborsClassifier(), knn_params, cv=5)
grid_search_knn.fit(X_train, y_train)
print(f'Best KNN Params: {grid_search_knn.best_params_}')

# Decision Tree Hyperparameter tuning
dt_params = {'max_depth': [3, 5, 7, 9]}
grid_search_dt = GridSearchCV(DecisionTreeClassifier(), dt_params, cv=5)
grid_search_dt.fit(X_train, y_train)
print(f'Best Decision Tree Params: {grid_search_dt.best_params_}')
# Out:
# Best KNN Params: {'n_neighbors': 7}
# Best Decision Tree Params: {'max_depth': 5}

# %% [markdown]
# ### **Task 18**: Plot the ROC curves and calculate the AUC for all models to compare their performance visually.

# %%
from sklearn.metrics import roc_curve, auc

# Logistic Regression ROC curve
y_pred_prob_lr = lr_model.predict_proba(X_test)[:, 1]
fpr_lr, tpr_lr, _ = roc_curve(y_test, y_pred_prob_lr)
roc_auc_lr = auc(fpr_lr, tpr_lr)

# Plot ROC curve for Logistic Regression
plt.figure(figsize=(8, 6))
plt.plot(fpr_lr, tpr_lr, label=f'Logistic Regression (AUC = {roc_auc_lr:.2f})')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# # Part-7
# ### 7. Conclusion
# - **Task 19**: Summarize your findings and explain which model performed best and why. Consider which features were most important for predicting the death event.
# - **Task 20**: Suggest potential improvements or next steps for the analysis.

# %% [markdown]
# ### **Task 19**: Summarize your findings and explain which model performed best and why. Consider which features were most important for predicting the death event.

# %%
# Feature importance for Decision Tree
feature_importances = dt_model.feature_importances_
importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)
print(importance_df)
# Out:
#                      Feature  Importance
# 11                      time    0.556677
# 7           serum_creatinine    0.137185
# 6                  platelets    0.079477
# 2   creatinine_phosphokinase    0.075145
# 4          ejection_fraction    0.056885
# 8               serum_sodium    0.049593
# 0                        age    0.027327
# 9                        sex    0.011808
# 10                   smoking    0.005904
# 1                    anaemia    0.000000
# 3                   diabetes    0.000000
# 5        high_blood_pressure    0.000000

# %% [markdown]
# ###  **Task 20**: Suggest potential improvements or next steps for the analysis.

# %%
# Example of hyperparameter tuning for Decision Tree
from sklearn.model_selection import GridSearchCV

param_grid = {'max_depth': [3, 5, 7, 9], 'min_samples_split': [2, 5, 10]}
grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5)
grid_search.fit(X_train, y_train)
print(f'Best Parameters: {grid_search.best_params_}')
# Out:
# Best Parameters: {'max_depth': 3, 'min_samples_split': 2}
