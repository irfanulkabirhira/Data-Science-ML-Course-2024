# %%
import pandas as pd # for DataFram 
import numpy as np #For Array 
from sklearn.linear_model import LinearRegression

# %%
Weight = np.array([2, 4, 5, 3,6,5,7]) # Inpdendent Variable
Price = np.array([35, 60, 20, 50,50,55,60])  # Dependent Variable

# %% [markdown]
# # Create the Dataframe

# %%
df = pd.DataFrame({'Weight': Weight, 'Price': Price})
df
# Out:
#    Weight  Price
# 0       2     35
# 1       4     60
# 2       5     20
# 3       3     50
# 4       6     50
# 5       5     55
# 6       7     60

# %% [markdown]
# # Task 1 :-

# %% [markdown]
# #### Your objective is to manually compute the slope (M) and y-intercept (C) using Ordinary Least Squares Linear Regression. Once determined, apply these values to predict the price when the vegetable weight is 6.

# %% [markdown]
# # Manually Compute the Slope M and C --> Using OLS [Ordinary list Square]

# %%
# Number of data points
N = len(Weight) 

# # Compute sums needed for the formulas
sum_Weight = np.sum(Weight) 
sum_Price = np.sum(Price) 
sum_Weight_Price = np.sum(Weight * Price) #MULTIPLICATION
sum_Weight2 = np.sum(Weight**2) #SQUARE

M = (N * sum_Weight_Price - sum_Weight * sum_Price) / (N * sum_Weight2 - sum_Weight**2)
C = (sum_Price - slope_formula1 * sum_Weight) / N

# %%
#The Slope is m = 2.62...
M
# Out:
# np.float64(2.620967741935484)

# %%
# The Intercept is c = 35.161....
C
# Out:
# np.float64(35.16129032258065)

# %%
# Output slope and intercept
print(f"Slope (M): {M}")
print(f"Intercept (C): {C}")
# Out:
# Slope (M): 2.620967741935484
# Intercept (C): 35.16129032258065

# %% [markdown]
# # 2nd part
# ####  apply these values to predict the price when the vegetable weight is 6

# %%
# Predict price when Weight = 6
Weight_to_predict = 6

# Applying Y = mx + c [where m =2.62 , C = 35.161 ]
predicted_price = M * Weight_to_predict + C
print(f"Predicted Price when Weight is {Weight_to_predict}: {predicted_price}")
# Out:
# Predicted Price when Weight is 6: 50.88709677419355

# %% [markdown]
# # Task 2 :-

# %% [markdown]
# #### Compute the residuals for each data point.

# %%
df.head()
# Out:
#    Weight  Price
# 0       2     35
# 1       4     60
# 2       5     20
# 3       3     50
# 4       6     50

# %%
x = df.drop('Price', axis=1)
x.head()
# Out:
#    Weight
# 0       2
# 1       4
# 2       5
# 3       3
# 4       6

# %%
y = df.drop('Weight', axis=1)
y.head()
# Out:
#    Price
# 0     35
# 1     60
# 2     20
# 3     50
# 4     50

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
df['residuals'] = df[['Price']] - reg.predict(x)
df.head()
# Out:
#    Weight  Price  residuals
# 0       2     35  -5.403226
# 1       4     60  14.354839
# 2       5     20 -28.266129
# 3       3     50   6.975806
# 4       6     50  -0.887097

# %% [markdown]
# # Task 3 :-
#
# #### Calculate both the Mean Squared Error (MSE) and Mean Absolute Error (MAE)

# %%
df['predict'] = reg.predict(x) 
df.head()
# Out:
#    Weight  Price  residuals    predict
# 0       2     35  -5.403226  40.403226
# 1       4     60  14.354839  45.645161
# 2       5     20 -28.266129  48.266129
# 3       3     50   6.975806  43.024194
# 4       6     50  -0.887097  50.887097

# %%
# To find the MSE ,MAE(Residuals) The Below code is the Formula--> 
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# To find the MSE 
mse = mean_squared_error(df['Price'] , df['predict'])
mse
# Out:
# np.float64(167.30990783410135)

# %%
# To find the MAE
mae=mean_absolute_error(df['Price'] , df['predict'])
mae
# Out:
# np.float64(9.87327188940092)

# %% [markdown]
# # Final Task :-
#
# #### Generate an Excel file for the given dataset. Utilize Python for all the calculations.

# %%
df.to_csv(r'E:\Data Science and ML Course\Class-4\The Final Model File.csv')
